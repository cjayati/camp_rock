# %%
# Import Dependencies
# %matplotlib inline 
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
path = "IMDB Movies 2000 - 2020_clean_Jas.csv"

all_data = pd.read_csv(path)

all_data.head()
# Out:
#    original_title  year                         genre  duration  \
# 0  Kate & Leopold  2001      Comedy, Fantasy, Romance       118
# 1         Glitter  2001         Drama, Music, Romance       104
# 2     Chicken Run  2000  Animation, Adventure, Comedy        84
# 3  Fantastic Four  2005    Action, Adventure, Fantasy       106
# 4           Frida  2002     Biography, Drama, Romance       123
#
#                country language_1               director  \
# 0                  USA    English          James Mangold
# 1                  USA    English     Vondie Curtis-Hall
# 2      UK, USA, France    English  Peter Lord, Nick Park
# 3         USA, Germany    English              Tim Story
# 4  Mexico, USA, Canada    English           Julie Taymor
#
#                          writer  \
# 0  Steven Rogers, James Mangold
# 1   Cheryl L. West, Kate Lanier
# 2         Peter Lord, Nick Park
# 3    Mark Frost, Michael France
# 4  Hayden Herrera, Clancy Sigal
#
# ...
